# %%
import requests # to handle requests
import pandas as pd # for data analsysis
import numpy as np # to handle data in a vectorized manner

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
#tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-2.0.0                |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-2.0.0-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
# geopy-2.0.0          | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36h8c4c3a4_1000         346 KB  conda-forge
#     chardet-3.0.4              |py36h9f0ad1d_1006         188 KB  conda-forge
#     cryptography-3.0           |   py36h45558ae_0         640 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     pandas-1.0.5               |   py36h830a2c2_0        10.1 MB  conda-forge
#     pysocks-1.7.1              |   py36h9f0ad1d_1          27 KB  conda-forge
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     urllib3-1.25.10            |             py_0          92 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        12.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-19.3.0-py_0
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36h8c4c3a4_1000
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9f0ad1d_1006
#   cryptography       conda-forge/linux-64::cryptography-3.0-py36h45558ae_0
#   entrypoints        conda-forge/linux-64::entrypoints-0.3-py36h9f0ad1d_1001
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.10-pyh9f0ad1d_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-1.7.0-0
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/linux-64::jsonschema-3.2.0-py36h9f0ad1d_1
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36h8c4c3a4_1
#   pandas             conda-forge/linux-64::pandas-1.0.5-py36h830a2c2_0
#   pyopenssl          conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.16.0-py36h8c4c3a4_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9f0ad1d_1
#   pytz               conda-forge/noarch::pytz-2020.1-pyh9f0ad1d_0
#   requests           conda-forge/noarch::requests-2.24.0-pyh9f0ad1d_0
#   toolz              conda-forge/noarch::toolz-0.10.0-py_0
#   urllib3            conda-forge/noarch::urllib3-1.25.10-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
#
#
# Downloading and Extracting Packages
# urllib3-1.25.10      | 92 KB     | ##################################### | 100%
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# toolz-0.10.0         | 46 KB     | ##################################### | 100%
# chardet-3.0.4        | 188 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# cryptography-3.0     | 640 KB    | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# brotlipy-0.7.0       | 346 KB    | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# pandas-1.0.5         | 10.1 MB   | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# ## Define foursquare credentials

# %%
ClIENT_ID = 'IFYHBS5DHCADMSLQKHLENQSFIFKFSMMHSLUTCWPM4HO4MI5H' # your Foursquare ID
ClIENT_SECRET = 'MRGFMOSL4AEOWUR3SUBJSZK2XSEZAVKNJDBCOFSOOV02XZHF' # your Foursquare Secret
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)
print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: IFYHBS5DHCADMSLQKHLENQSFIFKFSMMHSLUTCWPM4HO4MI5H
# Foursquare_Secret:MRGFMOSL4AEOWUR3SUBJSZK2XSEZAVKNJDBCOFSOOV02XZHF

# %% [markdown]
# ## Define the city, get latitude & longitude

# %%
city = 'Toronto'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.6534817 -79.3839347

# %% [markdown]
# ## Search for hotels

# %%
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=IFYHBS5DHCADMSLQKHLENQSFIFKFSMMHSLUTCWPM4HO4MI5H&client_secret=MRGFMOSL4AEOWUR3SUBJSZK2XSEZAVKNJDBCOFSOOV02XZHF&ll=43.6534817,-79.3839347&v=20180604&query=Hotel&radius=500&limit=30'

# %%
# Sending the GET Request to examine results
results = requests.get(url).json()
#results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# changing venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                             name  \
# 0  4ab2d511f964a5209b6c20e3    Sheraton Centre Toronto Hotel
# 1  4ae61cf6f964a520caa421e3             Pantages Hotel & Spa
# 2  51d212c3498ebf27dc469bc9                    Chelsea Hotel
# 3  4af96fbbf964a520c01122e3  One King West Hotel & Residence
# 4  4b68aed1f964a520de862be3   The Rex Hotel Jazz & Blues Bar
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1595798967    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1595798967    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1595798967    False
# 3  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1595798967    False
# 4  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...  v-1595798967    False
#
#          location.address location.crossStreet  location.lat  location.lng  \
# 0   123 Queen Street West          at York St.     43.650594    -79.384530
# 1         200 Victoria St         at Shuter St     43.654498    -79.379035
# 2  33 Gerrard Street West          at Yonge St     43.658498    -79.383097
# 3             1 King St W         at Yonge St.     43.649139    -79.377876
# 4          194 Queen St W  Queen & St. Patrick     43.650505    -79.388577
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...                324
# 1  [{'label': 'display', 'lat': 43.65449797039222...                410
# 2  [{'label': 'display', 'lat': 43.65849759157591...                562
# 3  [{'label': 'display', 'lat': 43.6491395, 'lng'...                686
# 4  [{'label': 'display', 'lat': 43.65050475544005...                499
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5H 2M9          CA       Toronto             ON
# 1                 NaN          CA       Toronto             ON
# 2             M5G 1Z4          CA       Toronto             ON
# 3             M5H 1A1          CA       Toronto             ON
# 4             M5V 1Z1          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [123 Queen Street West (at York St.), Toronto ...
# 1           Canada  [200 Victoria St (at Shuter St), Toronto ON, C...
# 2           Canada  [33 Gerrard Street West (at Yonge St), Toronto...
# 3           Canada  [1 King St W (at Yonge St.), Toronto ON M5H 1A...
# 4           Canada  [194 Queen St W (Queen & St. Patrick), Toronto...
#
#   venuePage.id location.neighborhood
# 0          NaN                   NaN
# 1          NaN                   NaN
# 2          NaN                   NaN
# 3          NaN                   NaN
# 4     62225795                   NaN

# %% [markdown]
# ### clean dataframe

# %%
# keep columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# extracting venue category
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filtering category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                               name categories                 address  \
# 0    Sheraton Centre Toronto Hotel      Hotel   123 Queen Street West
# 1             Pantages Hotel & Spa      Hotel         200 Victoria St
# 2                    Chelsea Hotel      Hotel  33 Gerrard Street West
# 3  One King West Hotel & Residence      Hotel             1 King St W
# 4   The Rex Hotel Jazz & Blues Bar  Jazz Club          194 Queen St W
#
#            crossStreet        lat        lng  \
# 0          at York St.  43.650594 -79.384530
# 1         at Shuter St  43.654498 -79.379035
# 2          at Yonge St  43.658498 -79.383097
# 3         at Yonge St.  43.649139 -79.377876
# 4  Queen & St. Patrick  43.650505 -79.388577
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.6505944, 'lng'...       324    M5H 2M9  CA
# 1  [{'label': 'display', 'lat': 43.65449797039222...       410        NaN  CA
# 2  [{'label': 'display', 'lat': 43.65849759157591...       562    M5G 1Z4  CA
# 3  [{'label': 'display', 'lat': 43.6491395, 'lng'...       686    M5H 1A1  CA
# 4  [{'label': 'display', 'lat': 43.65050475544005...       499    M5V 1Z1  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [123 Queen Street West (at York St.), Toronto ...
# 1  Toronto    ON  Canada  [200 Victoria St (at Shuter St), Toronto ON, C...
# 2  Toronto    ON  Canada  [33 Gerrard Street West (at Yonge St), Toronto...
# 3  Toronto    ON  Canada  [1 King St W (at Yonge St.), Toronto ON M5H 1A...
# 4  Toronto    ON  Canada  [194 Queen St W (Queen & St. Patrick), Toronto...
#
#   neighborhood                        id
# 0          NaN  4ab2d511f964a5209b6c20e3
# 1          NaN  4ae61cf6f964a520caa421e3
# 2          NaN  51d212c3498ebf27dc469bc9
# 3          NaN  4af96fbbf964a520c01122e3
# 4          NaN  4b68aed1f964a520de862be3

# %%
#further cleaning
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs','neighborhood', 'id'], axis=1)
clean_dataframe2
# Out:
#                                               name  \
# 0                    Sheraton Centre Toronto Hotel
# 1                             Pantages Hotel & Spa
# 2                                    Chelsea Hotel
# 3                  One King West Hotel & Residence
# 4                   The Rex Hotel Jazz & Blues Bar
# 5                    Crew Room Eaton Chelsea Hotel
# 6                                   VFM Test Hotel
# 7          Cosmopolitan Toronto Centre Hotel & Spa
# 8                                  Stathcona Hotel
# 9                Sheraton Centre Hotel Club Lounge
# 10                                  Pentagos hotel
# 11  Sheraton Centre Toronto Hotel - Grand Ballroom
# 12                Shizen Spa at the Pantages Hotel
# 13                                       650 Hotel
# 14                               Be SixFifty Hotel
# 15                   Pantages Hotel Toronto Centre
# 16                              Pantages Hotel Gym
# 17                    Bond Place Hotel Parking Lot
# 18                   The Spa At The Adelaide Hotel
# 19         Smoldering remains of the Empress Hotel
# 20  Chelsea Hotel, Toronto Meetings & Events Venue
# 21                                  St Regis Hotel
# 22                      The Adelaide Hotel Toronto
# 23              Henri's Bar at One King West hotel
# 24           Suites at One King West Hotel Toronto
# 25                            DoubleTree by Hilton
# 26                           89 Chestnut Residence
# 27    Marriott Downtown at CF Toronto Eaton Centre
# 28                                          Hilton
# 29                                  Fitness Centre
#
#                                   categories                        address  \
# 0                                      Hotel          123 Queen Street West
# 1                                      Hotel                200 Victoria St
# 2                                      Hotel         33 Gerrard Street West
# 3                                      Hotel                    1 King St W
# 4                                  Jazz Club                 194 Queen St W
# 5                                      Hotel         33 Gerrard Street West
# 6                                      Hotel                 123 Test Drive
# 7                                      Hotel                  8 Colborne St
# 8                                      Hotel                            NaN
# 9                                     Lounge                            NaN
# 10  Residential Building (Apartment / Condo)                            NaN
# 11                                  Ballroom          123 Queen Street West
# 12                                       Spa                200 Victoria St
# 13                                     Hotel                 650 Bay Street
# 14                                     Hotel                 650 Bay Street
# 15  Residential Building (Apartment / Condo)            200 Victoria Street
# 16                                       Gym               200 Victoria St.
# 17                        Miscellaneous Shop                Bond And Dundas
# 18                                       Spa                     325 Bay St
# 19                                     Hotel                   335 Yonge St
# 20                         Convention Center         33 Gerrard Street West
# 21                                     Hotel                     325 Bay St
# 22                                     Hotel                     325 Bay St
# 23                       American Restaurant                    1 King West
# 24                                     Hotel  1 King St W Toronto ON Canada
# 25                                     Hotel            108 Chestnut Street
# 26                    College Residence Hall                89 Chestnut St.
# 27                                     Hotel                 525 Bay Street
# 28                                     Hotel              145 Richmond St W
# 29                                       Gym                    525 Bay St.
#
#           lat        lng postalCode state
# 0   43.650594 -79.384530    M5H 2M9    ON
# 1   43.654498 -79.379035        NaN    ON
# 2   43.658498 -79.383097    M5G 1Z4    ON
# 3   43.649139 -79.377876    M5H 1A1    ON
# 4   43.650505 -79.388577    M5V 1Z1    ON
# 5   43.658094 -79.382711        NaN    ON
# 6   43.658434 -79.387894    M2M 2M2    ON
# 7   43.649064 -79.377598    M5E 1E1    ON
# 8   43.654947 -79.386359        NaN    ON
# 9   43.651063 -79.384527    M5H 2M9    ON
# 10  43.653976 -79.379875        NaN    ON
# 11  43.651200 -79.384520        NaN    ON
# 12  43.655198 -79.379913        NaN    ON
# 13  43.657046 -79.384411        NaN    ON
# 14  43.657120 -79.384560        NaN    ON
# 15  43.655205 -79.379182    M5B 1V8    ON
# 16  43.654464 -79.379036    M5B 1V8    ON
# 17  43.656224 -79.378830        NaN   NaN
# 18  43.649725 -79.380346    M5H 4G5    ON
# 19  43.657956 -79.381698        NaN    ON
# 20  43.658446 -79.382985    M5G 1Z4    ON
# 21  43.649770 -79.380701    M5H 4G3    ON
# 22  43.649831 -79.380164    M5H 4G3    ON
# 23  43.648945 -79.378028        NaN    ON
# 24  43.649077 -79.378468        NaN    ON
# 25  43.654608 -79.385942    M5G 1R3    ON
# 26  43.654160 -79.385291    M5G 1R1    ON
# 27  43.654728 -79.382422    M5G 2L2    ON
# 28  43.649946 -79.385479    M5H 2L2    ON
# 29  43.654690 -79.381739    M5G 2L2    ON

# %%
# further cleaning
# delete rows with NaN values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                                               name  \
# 0                    Sheraton Centre Toronto Hotel
# 2                                    Chelsea Hotel
# 3                  One King West Hotel & Residence
# 4                   The Rex Hotel Jazz & Blues Bar
# 6                                   VFM Test Hotel
# 7          Cosmopolitan Toronto Centre Hotel & Spa
# 15                   Pantages Hotel Toronto Centre
# 16                              Pantages Hotel Gym
# 18                   The Spa At The Adelaide Hotel
# 20  Chelsea Hotel, Toronto Meetings & Events Venue
# 21                                  St Regis Hotel
# 22                      The Adelaide Hotel Toronto
# 25                            DoubleTree by Hilton
# 26                           89 Chestnut Residence
# 27    Marriott Downtown at CF Toronto Eaton Centre
# 28                                          Hilton
# 29                                  Fitness Centre
#
#                                   categories                 address  \
# 0                                      Hotel   123 Queen Street West
# 2                                      Hotel  33 Gerrard Street West
# 3                                      Hotel             1 King St W
# 4                                  Jazz Club          194 Queen St W
# 6                                      Hotel          123 Test Drive
# 7                                      Hotel           8 Colborne St
# 15  Residential Building (Apartment / Condo)     200 Victoria Street
# 16                                       Gym        200 Victoria St.
# 18                                       Spa              325 Bay St
# 20                         Convention Center  33 Gerrard Street West
# 21                                     Hotel              325 Bay St
# 22                                     Hotel              325 Bay St
# 25                                     Hotel     108 Chestnut Street
# 26                    College Residence Hall         89 Chestnut St.
# 27                                     Hotel          525 Bay Street
# 28                                     Hotel       145 Richmond St W
# 29                                       Gym             525 Bay St.
#
#           lat        lng postalCode state
# 0   43.650594 -79.384530    M5H 2M9    ON
# 2   43.658498 -79.383097    M5G 1Z4    ON
# 3   43.649139 -79.377876    M5H 1A1    ON
# 4   43.650505 -79.388577    M5V 1Z1    ON
# 6   43.658434 -79.387894    M2M 2M2    ON
# 7   43.649064 -79.377598    M5E 1E1    ON
# 15  43.655205 -79.379182    M5B 1V8    ON
# 16  43.654464 -79.379036    M5B 1V8    ON
# 18  43.649725 -79.380346    M5H 4G5    ON
# 20  43.658446 -79.382985    M5G 1Z4    ON
# 21  43.649770 -79.380701    M5H 4G3    ON
# 22  43.649831 -79.380164    M5H 4G3    ON
# 25  43.654608 -79.385942    M5G 1R3    ON
# 26  43.654160 -79.385291    M5G 1R1    ON
# 27  43.654728 -79.382422    M5G 2L2    ON
# 28  43.649946 -79.385479    M5H 2L2    ON
# 29  43.654690 -79.381739    M5G 2L2    ON

# %%
# further cleaning
# delete rows where category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                                             name categories  \
# 0                  Sheraton Centre Toronto Hotel      Hotel
# 2                                  Chelsea Hotel      Hotel
# 3                One King West Hotel & Residence      Hotel
# 6                                 VFM Test Hotel      Hotel
# 7        Cosmopolitan Toronto Centre Hotel & Spa      Hotel
# 21                                St Regis Hotel      Hotel
# 22                    The Adelaide Hotel Toronto      Hotel
# 25                          DoubleTree by Hilton      Hotel
# 27  Marriott Downtown at CF Toronto Eaton Centre      Hotel
# 28                                        Hilton      Hotel
#
#                    address        lat        lng postalCode state
# 0    123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 2   33 Gerrard Street West  43.658498 -79.383097    M5G 1Z4    ON
# 3              1 King St W  43.649139 -79.377876    M5H 1A1    ON
# 6           123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 7            8 Colborne St  43.649064 -79.377598    M5E 1E1    ON
# 21              325 Bay St  43.649770 -79.380701    M5H 4G3    ON
# 22              325 Bay St  43.649831 -79.380164    M5H 4G3    ON
# 25     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 27          525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 28       145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON

# %%
# further cleaning
# delete rows where name of hotel is repeated
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                                             name categories  \
# 0                  Sheraton Centre Toronto Hotel      Hotel
# 2                                  Chelsea Hotel      Hotel
# 3                One King West Hotel & Residence      Hotel
# 6                                 VFM Test Hotel      Hotel
# 7        Cosmopolitan Toronto Centre Hotel & Spa      Hotel
# 21                                St Regis Hotel      Hotel
# 22                    The Adelaide Hotel Toronto      Hotel
# 25                          DoubleTree by Hilton      Hotel
# 27  Marriott Downtown at CF Toronto Eaton Centre      Hotel
# 28                                        Hilton      Hotel
#
#                    address        lat        lng postalCode state
# 0    123 Queen Street West  43.650594 -79.384530    M5H 2M9    ON
# 2   33 Gerrard Street West  43.658498 -79.383097    M5G 1Z4    ON
# 3              1 King St W  43.649139 -79.377876    M5H 1A1    ON
# 6           123 Test Drive  43.658434 -79.387894    M2M 2M2    ON
# 7            8 Colborne St  43.649064 -79.377598    M5E 1E1    ON
# 21              325 Bay St  43.649770 -79.380701    M5H 4G3    ON
# 22              325 Bay St  43.649831 -79.380164    M5H 4G3    ON
# 25     108 Chestnut Street  43.654608 -79.385942    M5G 1R3    ON
# 27          525 Bay Street  43.654728 -79.382422    M5G 2L2    ON
# 28       145 Richmond St W  43.649946 -79.385479    M5H 2L2    ON

# %%
# choose the hotel which has the same postalCode with the conference place
df_hotel = df_hotels[df_hotels.postalCode == 'M5H 4G3']
df_hotel
# Out:
#                           name categories     address        lat        lng  \
# 21              St Regis Hotel      Hotel  325 Bay St  43.649770 -79.380701
# 22  The Adelaide Hotel Toronto      Hotel  325 Bay St  43.649831 -79.380164
#
#    postalCode state
# 21    M5H 4G3    ON
# 22    M5H 4G3    ON

# %% [markdown]
# ## Searching for parks/landmarks

# %%
search_query = 'Park'
radius = 15000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=IFYHBS5DHCADMSLQKHLENQSFIFKFSMMHSLUTCWPM4HO4MI5H&client_secret=MRGFMOSL4AEOWUR3SUBJSZK2XSEZAVKNJDBCOFSOOV02XZHF&ll=43.6534817,-79.3839347&v=20180604&query=Park&radius=15000&limit=30'

# %%
# Sending GET Request to see results
presults = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = presults['response']['venues']

# changing venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                                name  \
# 0  4b170e47f964a5208cc123e3         Queen's Park Subway Station
# 1  4b54deadf964a520a3d027e3                         Grange Park
# 2  4b9d206bf964a520e69136e3                        Queen's Park
# 3  4bfc5019da7120a132df49fd   St. Andrews Playground / Dog Park
# 4  4b9177e4f964a520d2be33e3  TTC Streetcar #403 - Victoria park
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...  v-1595799986    False
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1595799986    False
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1595799986    False
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1595799986    False
# 4  [{'id': '4bf58dd8d48988d1fc931735', 'name': 'L...  v-1595799986    False
#
#            location.address      location.crossStreet  location.lat  \
# 0        691 University Ave             at College St     43.660006
# 1                       NaN                       NaN     43.652488
# 2           University Ave.         at Wellesley Ave.     43.663946
# 3  450 Adelaide Street West  Brant St & Adelaide St W     43.647388
# 4                       NaN                       NaN     43.650735
#
#    location.lng                            location.labeledLatLngs  \
# 0    -79.390272  [{'label': 'display', 'lat': 43.66000635700919...
# 1    -79.392053  [{'label': 'display', 'lat': 43.65248755299856...
# 2    -79.392180  [{'label': 'display', 'lat': 43.66394609897775...
# 3    -79.398752  [{'label': 'display', 'lat': 43.64738759338116...
# 4    -79.386921  [{'label': 'display', 'lat': 43.650735, 'lng':...
#
#    location.distance location.postalCode location.cc location.city  \
# 0                887             M5G 2P1          CA       Toronto
# 1                663                 NaN          CA       Toronto
# 2               1340             M5R 2E8          CA       Toronto
# 3               1372                 NaN          CA       Toronto
# 4                389                 NaN          CA       Toronto
#
#   location.state location.country  \
# 0             ON           Canada
# 1             ON           Canada
# 2             ON           Canada
# 3             ON           Canada
# 4             ON           Canada
#
#                            location.formattedAddress venuePage.id
# 0  [691 University Ave (at College St), Toronto O...          NaN
# 1  [btwn College, University, Queen & Spadina, To...          NaN
# 2  [University Ave. (at Wellesley Ave.), Toronto ...          NaN
# 3  [450 Adelaide Street West (Brant St & Adelaide...          NaN
# 4                               [Toronto ON, Canada]          NaN

# %% [markdown]
# ### Clean dataframe

# %%
# keep columns that include venue name, and anything associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filtering category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                                  name          categories  \
# 0         Queen's Park Subway Station       Metro Station
# 1                         Grange Park                Park
# 2                        Queen's Park                Park
# 3   St. Andrews Playground / Dog Park                Park
# 4  TTC Streetcar #403 - Victoria park  Light Rail Station
#
#                     address               crossStreet        lat        lng  \
# 0        691 University Ave             at College St  43.660006 -79.390272
# 1                       NaN                       NaN  43.652488 -79.392053
# 2           University Ave.         at Wellesley Ave.  43.663946 -79.392180
# 3  450 Adelaide Street West  Brant St & Adelaide St W  43.647388 -79.398752
# 4                       NaN                       NaN  43.650735 -79.386921
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.66000635700919...       887    M5G 2P1  CA
# 1  [{'label': 'display', 'lat': 43.65248755299856...       663        NaN  CA
# 2  [{'label': 'display', 'lat': 43.66394609897775...      1340    M5R 2E8  CA
# 3  [{'label': 'display', 'lat': 43.64738759338116...      1372        NaN  CA
# 4  [{'label': 'display', 'lat': 43.650735, 'lng':...       389        NaN  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [691 University Ave (at College St), Toronto O...
# 1  Toronto    ON  Canada  [btwn College, University, Queen & Spadina, To...
# 2  Toronto    ON  Canada  [University Ave. (at Wellesley Ave.), Toronto ...
# 3  Toronto    ON  Canada  [450 Adelaide Street West (Brant St & Adelaide...
# 4  Toronto    ON  Canada                               [Toronto ON, Canada]
#
#                          id
# 0  4b170e47f964a5208cc123e3
# 1  4b54deadf964a520a3d027e3
# 2  4b9d206bf964a520e69136e3
# 3  4bfc5019da7120a132df49fd
# 4  4b9177e4f964a520d2be33e3

# %%
#further cleaning
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                   name  \
# 0          Queen's Park Subway Station
# 1                          Grange Park
# 2                         Queen's Park
# 3    St. Andrews Playground / Dog Park
# 4   TTC Streetcar #403 - Victoria park
# 5                  Riverdale Park West
# 6                        One Park Lane
# 7               Trinity Bellwoods Park
# 8               Physiomed College Park
# 9                  Riverdale Park East
# 10                Bellevue Square Park
# 11                         Berczy Park
# 12                            HTO Park
# 13       Crunch Fitness - College Park
# 14                Clarence Square Park
# 15    Residences at College Park North
# 16    Toothworks - College Park Dental
# 17                  Canoe Landing Park
# 18             Moss Park Tennis Courts
# 19              Parliament Square Park
# 20                     Coronation Park
# 21        Orphan's Greenspace Dog Park
# 22                   Barbara Hall Park
# 23                   Barbara Hall Park
# 24             St Lawrence on the Park
# 25                 Tommy Thompson Park
# 26                         Regent Park
# 27                           High Park
# 28                        Stanley Park
# 29           Village of Yorkville Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 1                                       Park                           NaN
# 2                                       Park               University Ave.
# 3                                       Park      450 Adelaide Street West
# 4                         Light Rail Station                           NaN
# 5                                       Park               500 Gerrard St.
# 6   Residential Building (Apartment / Condo)                 280 Simcoe St
# 7                                       Park            1053 Dundas St. W.
# 8                             Medical Center                  382 Yonge St
# 9                                       Park             550 Broadview Ave
# 10                                      Park  btwn Bellevue & Augusta Ave.
# 11                                      Park        35 Wellington St. East
# 12                                      Park                  Queen's Quay
# 13                      Gym / Fitness Center              382 Yonge Street
# 14                                      Park                   Spadina Ave
# 15  Residential Building (Apartment / Condo)                   763 Bay St.
# 16                          Dentist's Office        444 Yonge St, Unit M16
# 17                                      Park             50 Fort York Blvd
# 18                              Tennis Court                     Moss Park
# 19                                      Park          44 Parliament Street
# 20                                      Park        711 Lake Shore Blvd. W
# 21                                   Dog Run                  51 Power St.
# 22                                      Park                 519 Church St
# 23                                      Park             519 Church Street
# 24                                  Building               65 Scadding Ave
# 25                                      Park                     Leslie St
# 26                              Neighborhood                           NaN
# 27                                      Park              1873 Bloor St. W
# 28                                      Park              King Street West
# 29                                      Park            115 Cumberland St.
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 1   43.652488 -79.392053        NaN    ON
# 2   43.663946 -79.392180    M5R 2E8    ON
# 3   43.647388 -79.398752        NaN    ON
# 4   43.650735 -79.386921        NaN    ON
# 5   43.666048 -79.360941    M5A 2H3    ON
# 6   43.655442 -79.390056    M5T 2Y5    ON
# 7   43.647072 -79.413756    M5H 2N2    ON
# 8   43.659240 -79.382860    M5B 1S8    ON
# 9   43.669951 -79.355493    M4K 2P1    ON
# 10  43.653610 -79.402199    M5T 2N4    ON
# 11  43.648048 -79.375172        NaN    ON
# 12  43.637949 -79.387820        NaN    ON
# 13  43.659263 -79.382632    M5G 1S8    ON
# 14  43.644222 -79.394230        NaN    ON
# 15  43.659822 -79.385159    M5G 2R3    ON
# 16  43.660009 -79.383905        NaN    ON
# 17  43.638762 -79.397067    M5V 3Z1    ON
# 18  43.655337 -79.371923        NaN    ON
# 19  43.650264 -79.362195        NaN    ON
# 20  43.634553 -79.405403    M5V 3T7    ON
# 21  43.654654 -79.362501        NaN    ON
# 22  43.666879 -79.381068    M4Y 2K9    ON
# 23  43.666728 -79.381084        NaN    ON
# 24  43.648963 -79.364868        NaN    ON
# 25  43.634180 -79.323671        NaN    ON
# 26  43.660009 -79.364191        NaN    ON
# 27  43.646479 -79.463425    M6R 2Z3    ON
# 28  43.642395 -79.409330        NaN    ON
# 29  43.670186 -79.391180        NaN    ON

# %%
#further cleaning
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                 name  \
# 0        Queen's Park Subway Station
# 2                       Queen's Park
# 5                Riverdale Park West
# 6                      One Park Lane
# 7             Trinity Bellwoods Park
# 8             Physiomed College Park
# 9                Riverdale Park East
# 10              Bellevue Square Park
# 13     Crunch Fitness - College Park
# 15  Residences at College Park North
# 17                Canoe Landing Park
# 20                   Coronation Park
# 22                 Barbara Hall Park
# 27                         High Park
#
#                                   categories                       address  \
# 0                              Metro Station            691 University Ave
# 2                                       Park               University Ave.
# 5                                       Park               500 Gerrard St.
# 6   Residential Building (Apartment / Condo)                 280 Simcoe St
# 7                                       Park            1053 Dundas St. W.
# 8                             Medical Center                  382 Yonge St
# 9                                       Park             550 Broadview Ave
# 10                                      Park  btwn Bellevue & Augusta Ave.
# 13                      Gym / Fitness Center              382 Yonge Street
# 15  Residential Building (Apartment / Condo)                   763 Bay St.
# 17                                      Park             50 Fort York Blvd
# 20                                      Park        711 Lake Shore Blvd. W
# 22                                      Park                 519 Church St
# 27                                      Park              1873 Bloor St. W
#
#           lat        lng postalCode state
# 0   43.660006 -79.390272    M5G 2P1    ON
# 2   43.663946 -79.392180    M5R 2E8    ON
# 5   43.666048 -79.360941    M5A 2H3    ON
# 6   43.655442 -79.390056    M5T 2Y5    ON
# 7   43.647072 -79.413756    M5H 2N2    ON
# 8   43.659240 -79.382860    M5B 1S8    ON
# 9   43.669951 -79.355493    M4K 2P1    ON
# 10  43.653610 -79.402199    M5T 2N4    ON
# 13  43.659263 -79.382632    M5G 1S8    ON
# 15  43.659822 -79.385159    M5G 2R3    ON
# 17  43.638762 -79.397067    M5V 3Z1    ON
# 20  43.634553 -79.405403    M5V 3T7    ON
# 22  43.666879 -79.381068    M4Y 2K9    ON
# 27  43.646479 -79.463425    M6R 2Z3    ON

# %%
# further cleaning
# delete rows where category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                       name categories                       address  \
# 2             Queen's Park       Park               University Ave.
# 5      Riverdale Park West       Park               500 Gerrard St.
# 7   Trinity Bellwoods Park       Park            1053 Dundas St. W.
# 9      Riverdale Park East       Park             550 Broadview Ave
# 10    Bellevue Square Park       Park  btwn Bellevue & Augusta Ave.
# 17      Canoe Landing Park       Park             50 Fort York Blvd
# 20         Coronation Park       Park        711 Lake Shore Blvd. W
# 22       Barbara Hall Park       Park                 519 Church St
# 27               High Park       Park              1873 Bloor St. W
#
#           lat        lng postalCode state
# 2   43.663946 -79.392180    M5R 2E8    ON
# 5   43.666048 -79.360941    M5A 2H3    ON
# 7   43.647072 -79.413756    M5H 2N2    ON
# 9   43.669951 -79.355493    M4K 2P1    ON
# 10  43.653610 -79.402199    M5T 2N4    ON
# 17  43.638762 -79.397067    M5V 3Z1    ON
# 20  43.634553 -79.405403    M5V 3T7    ON
# 22  43.666879 -79.381068    M4Y 2K9    ON
# 27  43.646479 -79.463425    M6R 2Z3    ON

# %% [markdown]
# ## Searching restaurants

# %%
search_query = 'Restaurant'
radius = 15000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=IFYHBS5DHCADMSLQKHLENQSFIFKFSMMHSLUTCWPM4HO4MI5H&client_secret=MRGFMOSL4AEOWUR3SUBJSZK2XSEZAVKNJDBCOFSOOV02XZHF&ll=43.6534817,-79.3839347&v=20180604&query=Restaurant&radius=15000&limit=30'

# %%
# Sending GET Request to see results
Rresults = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# changing venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                                name  \
# 0  4ada5d5bf964a520e92121e3      The Hot House Restaurant & Bar
# 1  4ad4c05ff964a52048f720e3     Hemispheres Restaurant & Bistro
# 2  4ad4c05cf964a52006f620e3               Victoria's Restaurant
# 3  4ad4c060f964a5207ff720e3              Rol San Restaurant 龍笙棧
# 4  5750b013498e755287c6de97  Some Time BBQ Grill Restaurant 碳烤屋
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1595800370    False
# 1  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1595800370    False
# 2  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1595800370    False
# 3  [{'id': '4bf58dd8d48988d1f5931735', 'name': 'D...  v-1595800370    False
# 4  [{'id': '52af3b773cf9994f4e043c03', 'name': 'S...  v-1595800370    False
#
#       location.address              location.crossStreet  location.lat  \
# 0         35 Church St                     at Front St E     43.648824
# 1  110 Chestnut Street                               NaN     43.654884
# 2  37 King Street East  at Le Meridien King Edward Hotel     43.649298
# 3     323 Spadina Ave.                     at D'Arcy St.     43.654318
# 4   988 Baldwin Street                               NaN     43.655874
#
#    location.lng                            location.labeledLatLngs  \
# 0    -79.373702  [{'label': 'display', 'lat': 43.64882370529773...
# 1    -79.385931  [{'label': 'display', 'lat': 43.65488413420439...
# 2    -79.376431  [{'label': 'display', 'lat': 43.64929834396347...
# 3    -79.398650  [{'label': 'display', 'lat': 43.65431754076345...
# 4    -79.393826  [{'label': 'display', 'lat': 43.655874, 'lng':...
#
#    location.distance location.postalCode location.cc location.city  \
# 0                973             M5E 1T3          CA       Toronto
# 1                224             M5G 1R3          CA       Toronto
# 2                763             M5C 1E9          CA       Toronto
# 3               1188             M5T 2E9          CA       Toronto
# 4                839                 NaN          CA       Toronto
#
#   location.state location.country  \
# 0             ON           Canada
# 1             ON           Canada
# 2             ON           Canada
# 3             ON           Canada
# 4             ON           Canada
#
#                            location.formattedAddress venuePage.id  \
# 0  [35 Church St (at Front St E), Toronto ON M5E ...          NaN
# 1  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]          NaN
# 2  [37 King Street East (at Le Meridien King Edwa...    498556908
# 3  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...          NaN
# 4           [988 Baldwin Street, Toronto ON, Canada]          NaN
#
#   location.neighborhood
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3     Kensington Market
# 4                   NaN

# %% [markdown]
# ### Clean dataframe

# %%
# keep columns that include venue name, and anything associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                                  name           categories  \
# 0      The Hot House Restaurant & Bar  American Restaurant
# 1     Hemispheres Restaurant & Bistro  American Restaurant
# 2               Victoria's Restaurant           Restaurant
# 3              Rol San Restaurant 龍笙棧   Dim Sum Restaurant
# 4  Some Time BBQ Grill Restaurant 碳烤屋  Szechuan Restaurant
#
#                address                       crossStreet        lat  \
# 0         35 Church St                     at Front St E  43.648824
# 1  110 Chestnut Street                               NaN  43.654884
# 2  37 King Street East  at Le Meridien King Edward Hotel  43.649298
# 3     323 Spadina Ave.                     at D'Arcy St.  43.654318
# 4   988 Baldwin Street                               NaN  43.655874
#
#          lng                                     labeledLatLngs  distance  \
# 0 -79.373702  [{'label': 'display', 'lat': 43.64882370529773...       973
# 1 -79.385931  [{'label': 'display', 'lat': 43.65488413420439...       224
# 2 -79.376431  [{'label': 'display', 'lat': 43.64929834396347...       763
# 3 -79.398650  [{'label': 'display', 'lat': 43.65431754076345...      1188
# 4 -79.393826  [{'label': 'display', 'lat': 43.655874, 'lng':...       839
#
#   postalCode  cc     city state country  \
# 0    M5E 1T3  CA  Toronto    ON  Canada
# 1    M5G 1R3  CA  Toronto    ON  Canada
# 2    M5C 1E9  CA  Toronto    ON  Canada
# 3    M5T 2E9  CA  Toronto    ON  Canada
# 4        NaN  CA  Toronto    ON  Canada
#
#                                     formattedAddress       neighborhood  \
# 0  [35 Church St (at Front St E), Toronto ON M5E ...                NaN
# 1  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]                NaN
# 2  [37 King Street East (at Le Meridien King Edwa...                NaN
# 3  [323 Spadina Ave. (at D'Arcy St.), Toronto ON ...  Kensington Market
# 4           [988 Baldwin Street, Toronto ON, Canada]                NaN
#
#                          id
# 0  4ada5d5bf964a520e92121e3
# 1  4ad4c05ff964a52048f720e3
# 2  4ad4c05cf964a52006f620e3
# 3  4ad4c060f964a5207ff720e3
# 4  5750b013498e755287c6de97

# %%
#further cleaning
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                               name               categories  \
# 0                   The Hot House Restaurant & Bar      American Restaurant
# 1                  Hemispheres Restaurant & Bistro      American Restaurant
# 2                            Victoria's Restaurant               Restaurant
# 3                           Rol San Restaurant 龍笙棧       Dim Sum Restaurant
# 4               Some Time BBQ Grill Restaurant 碳烤屋      Szechuan Restaurant
# 5                   Goldstone Noodle Restaurant 金石             Noodle House
# 6                     Aroma Fine Indian Restaurant        Indian Restaurant
# 7          Tasty's Caribbean Restaurant & Catering     Caribbean Restaurant
# 8                                Studio Restaurant           Breakfast Spot
# 9               North-East Chinese Restaurant 華北美食       Chinese Restaurant
# 10                          Azure Restaurant & Bar               Restaurant
# 11                   Green Tea Restaurant Downtown       Chinese Restaurant
# 12                     Cottage Restaurant & Lounge          Thai Restaurant
# 13              Sky Dragon Chinese Restaurant 龍翔酒樓       Dim Sum Restaurant
# 14               Kensington Cornerstone Restaurant           Breakfast Spot
# 15                        Ka Chi Korean Restaurant        Korean Restaurant
# 16                         Victor Restaurant & Bar                      Bar
# 17                         Swatow Restaurant 汕頭小食家       Chinese Restaurant
# 18                                  360 Restaurant                 Wine Bar
# 19                        New Sky Restaurant 小沙田食家       Chinese Restaurant
# 20  Sassafraz | Cafe | Restaurant | Private Events              Event Space
# 21                           Sightlines Restaurant      American Restaurant
# 22                 Kyoto House Japanese Restaurant         Sushi Restaurant
# 23                           Restaurant | Adelaide               Restaurant
# 24                           ONE Restaurant/Lounge  New American Restaurant
# 25                   Micheal's Restaurant and Deli                      Bar
# 26             Richtree Natural Market Restaurants               Restaurant
# 27                         Osgoode Hall Restaurant  New American Restaurant
# 28                         New Treasure Restaurant       Dim Sum Restaurant
# 29                    Yueh Tung Chinese Restaurant       Chinese Restaurant
#
#                             address        lat        lng postalCode state
# 0                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 1               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 2               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 3                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 4                988 Baldwin Street  43.655874 -79.393826        NaN    ON
# 5                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 6                    287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 7                   405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 8                    389 Church St.  43.661500 -79.379319        M5B    ON
# 9                    476 Dundas St.  43.653185 -79.396677        NaN    ON
# 10                   225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 11  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 12                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 13                 280 Spadina Ave.  43.652783 -79.398174        NaN    ON
# 14               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 15                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 16                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 17                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 18                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 19                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 20            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 21                    Rogers Centre  43.641635 -79.389365        NaN    ON
# 22              143 Dundas St. West  43.655381 -79.385270        NaN    ON
# 23          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 24                116 Yorkville Ave  43.670809 -79.393272        NaN    ON
# 25                   566 Queen St W  43.647289 -79.403493        NaN    ON
# 26                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 27                   130 Queen St W  43.651979 -79.385049    M5H 2N6   NaN
# 28                  150 Dundas St W  43.655384 -79.385362        NaN    ON
# 29                126 Elizabeth St.  43.655281 -79.385337    M5G 1P5    ON

# %%
#further cleaning
# delete rows with NaN values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                               name            categories  \
# 0                   The Hot House Restaurant & Bar   American Restaurant
# 1                  Hemispheres Restaurant & Bistro   American Restaurant
# 2                            Victoria's Restaurant            Restaurant
# 3                           Rol San Restaurant 龍笙棧    Dim Sum Restaurant
# 5                   Goldstone Noodle Restaurant 金石          Noodle House
# 6                     Aroma Fine Indian Restaurant     Indian Restaurant
# 7          Tasty's Caribbean Restaurant & Catering  Caribbean Restaurant
# 8                                Studio Restaurant        Breakfast Spot
# 10                          Azure Restaurant & Bar            Restaurant
# 11                   Green Tea Restaurant Downtown    Chinese Restaurant
# 12                     Cottage Restaurant & Lounge       Thai Restaurant
# 14               Kensington Cornerstone Restaurant        Breakfast Spot
# 15                        Ka Chi Korean Restaurant     Korean Restaurant
# 16                         Victor Restaurant & Bar                   Bar
# 17                         Swatow Restaurant 汕頭小食家    Chinese Restaurant
# 18                                  360 Restaurant              Wine Bar
# 19                        New Sky Restaurant 小沙田食家    Chinese Restaurant
# 20  Sassafraz | Cafe | Restaurant | Private Events           Event Space
# 23                           Restaurant | Adelaide            Restaurant
# 26             Richtree Natural Market Restaurants            Restaurant
# 29                    Yueh Tung Chinese Restaurant    Chinese Restaurant
#
#                             address        lat        lng postalCode state
# 0                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 1               110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 2               37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 3                  323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 5                   266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 6                    287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 7                   405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 8                    389 Church St.  43.661500 -79.379319        M5B    ON
# 10                   225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 11  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 12                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 14               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 15                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 16                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 17                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 18                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 19                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 20            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 23          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 26                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 29                126 Elizabeth St.  43.655281 -79.385337    M5G 1P5    ON

# %% [markdown]
# ## Searching cafeterias

# %%
search_query = 'Cafeteria'
radius = 15000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=IFYHBS5DHCADMSLQKHLENQSFIFKFSMMHSLUTCWPM4HO4MI5H&client_secret=MRGFMOSL4AEOWUR3SUBJSZK2XSEZAVKNJDBCOFSOOV02XZHF&ll=43.6534817,-79.3839347&v=20180604&query=Cafeteria&radius=15000&limit=30'

# %%
# Sending GET Request to see results
cresults = requests.get(url).json()
#cresults

# %%
# assign relevant part of JSON to venues
venues = cresults['response']['venues']

# changing venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                           name  \
# 0  4f9165bde4b04fef0087e4e2                      Cafeteria
# 1  528e99a211d262edc3708a6f              Stay Cafeteria 慢走
# 2  4b57256bf964a520332828e3                Sears Cafeteria
# 3  53bd6dfe498e6c1d3bc9333e  Industrial Alliance Cafeteria
# 4  524f1c8f498e983dde61ada0        Chestnut Tree Cafeteria
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...  v-1595800515    False
# 1  [{'id': '4bf58dd8d48988d142941735', 'name': 'A...  v-1595800515    False
# 2  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...  v-1595800515    False
# 3  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...  v-1595800515    False
# 4  [{'id': '4bf58dd8d48988d128941735', 'name': 'C...  v-1595800515    False
#
#                             location.address  location.lat  location.lng  \
# 0  The Hospital for Sick Children (SickKids)     43.657209    -79.386063
# 1                            388 Spadina Ave     43.655454    -79.399163
# 2                                      Yonge     43.656038    -79.380672
# 3                                        NaN     43.655657    -79.389443
# 4                         89 Chestnut Street     43.648231    -79.384045
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...                448
# 1  [{'label': 'display', 'lat': 43.65545427446646...               1246
# 2  [{'label': 'display', 'lat': 43.65603785909391...                387
# 3  [{'label': 'display', 'lat': 43.655657, 'lng':...                505
# 4  [{'label': 'display', 'lat': 43.648231, 'lng':...                584
#
#   location.cc location.city location.state location.country  \
# 0          CA       Toronto             ON           Canada
# 1          CA       Toronto             ON           Canada
# 2          CA       Toronto             ON           Canada
# 3          CA       Toronto             ON           Canada
# 4          CA       Toronto             ON           Canada
#
#                            location.formattedAddress location.crossStreet  \
# 0  [The Hospital for Sick Children (SickKids), To...                  NaN
# 1  [388 Spadina Ave (at Nassau St), Toronto ON M5...         at Nassau St
# 2               [Yonge (Dundas), Toronto ON, Canada]               Dundas
# 3                               [Toronto ON, Canada]                  NaN
# 4           [89 Chestnut Street, Toronto ON, Canada]                  NaN
#
#   location.postalCode
# 0                 NaN
# 1             M5T 2G5
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %% [markdown]
# ### Clean dataframe

# %%
# keep columns that include venue name, and anything associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                             name            categories  \
# 0                      Cafeteria  Fast Food Restaurant
# 1              Stay Cafeteria 慢走      Asian Restaurant
# 2                Sears Cafeteria            Food Court
# 3  Industrial Alliance Cafeteria             Cafeteria
# 4        Chestnut Tree Cafeteria             Cafeteria
#
#                                      address        lat        lng  \
# 0  The Hospital for Sick Children (SickKids)  43.657209 -79.386063
# 1                            388 Spadina Ave  43.655454 -79.399163
# 2                                      Yonge  43.656038 -79.380672
# 3                                        NaN  43.655657 -79.389443
# 4                         89 Chestnut Street  43.648231 -79.384045
#
#                                       labeledLatLngs  distance  cc     city  \
# 0  [{'label': 'display', 'lat': 43.65720930549997...       448  CA  Toronto
# 1  [{'label': 'display', 'lat': 43.65545427446646...      1246  CA  Toronto
# 2  [{'label': 'display', 'lat': 43.65603785909391...       387  CA  Toronto
# 3  [{'label': 'display', 'lat': 43.655657, 'lng':...       505  CA  Toronto
# 4  [{'label': 'display', 'lat': 43.648231, 'lng':...       584  CA  Toronto
#
#   state country                                   formattedAddress  \
# 0    ON  Canada  [The Hospital for Sick Children (SickKids), To...
# 1    ON  Canada  [388 Spadina Ave (at Nassau St), Toronto ON M5...
# 2    ON  Canada               [Yonge (Dundas), Toronto ON, Canada]
# 3    ON  Canada                               [Toronto ON, Canada]
# 4    ON  Canada           [89 Chestnut Street, Toronto ON, Canada]
#
#     crossStreet postalCode                        id
# 0           NaN        NaN  4f9165bde4b04fef0087e4e2
# 1  at Nassau St    M5T 2G5  528e99a211d262edc3708a6f
# 2        Dundas        NaN  4b57256bf964a520332828e3
# 3           NaN        NaN  53bd6dfe498e6c1d3bc9333e
# 4           NaN        NaN  524f1c8f498e983dde61ada0

# %%
#further cleaning
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                    name            categories  \
# 0                             Cafeteria  Fast Food Restaurant
# 1                     Stay Cafeteria 慢走      Asian Restaurant
# 2                       Sears Cafeteria            Food Court
# 3         Industrial Alliance Cafeteria             Cafeteria
# 4               Chestnut Tree Cafeteria             Cafeteria
# 5                       Dears Cafeteria          Dessert Shop
# 6                        OCAD Cafeteria     College Cafeteria
# 7                 Ryerson Hub Cafeteria     College Cafeteria
# 8                    SickKids Cafeteria            Food Court
# 9         De La Salle College Cafeteria     College Cafeteria
# 10                    Med Sci Cafeteria     College Cafeteria
# 11            Macdonald Block Cafeteria             Cafeteria
# 12                    Robarts Cafeteria     College Cafeteria
# 13                  Cafeteria (Newnham)     College Cafeteria
# 14                        OMP Cafeteria             Cafeteria
# 15                        The Cafeteria                 Diner
# 16                     Rogers Cafeteria            Food Court
# 17                    Choices Cafeteria            Food Court
# 18                 Windfields Cafeteria             Cafeteria
# 19                            Cafeteria            Food Court
# 20        Cafeteria, Centennial College     College Cafeteria
# 21  Cafeteria, Lawrence Park Collegiate           High School
# 22  Cafeteria, Lawrence Park Collegiate           Event Space
# 23                           Marketeria            Restaurant
# 24                              The Hub     College Cafeteria
# 25                     Kasala Cafeteria    African Restaurant
# 26             Estonian House Cafeteria                  Café
# 27         2201 Eglinton Ave. Cafeteria             Cafeteria
# 28    Bell Creekbank Eatery (Cafeteria)   Corporate Cafeteria
# 29                         CC Cafeteria     College Cafeteria
#
#                                       address        lat        lng state  \
# 0   The Hospital for Sick Children (SickKids)  43.657209 -79.386063    ON
# 1                             388 Spadina Ave  43.655454 -79.399163    ON
# 2                                       Yonge  43.656038 -79.380672    ON
# 3                                         NaN  43.655657 -79.389443    ON
# 4                          89 Chestnut Street  43.648231 -79.384045    ON
# 5                                         NaN  43.654179 -79.392555   NaN
# 6                              100 McCaul St.  43.652780 -79.391762    ON
# 7                            350 Victoria St.  43.658475 -79.377653    ON
# 8                       555 University Avenue  43.657584 -79.375652    ON
# 9                          131 Farnham Avenue  43.683003 -79.397815    ON
# 10                                        NaN  43.660260 -79.392977    ON
# 11                                        NaN  43.663212 -79.388062   NaN
# 12                         130 St. George St.  43.664864 -79.399766    ON
# 13         1750 Finch Ave. East Building D L1  43.795727 -79.348594    ON
# 14                           1 Mount Pleasant  43.669801 -79.379790    ON
# 15                                 Terminal 1  43.682246 -79.611691    ON
# 16                                        NaN  43.669904 -79.379748    ON
# 17                         200 Bloor Street E  43.671411 -79.381849    ON
# 18                                 Banbury Rd  43.755862 -79.370649    ON
# 19                             4001 Leslie St  43.769373 -79.362580    ON
# 20                           940 Progress Ave  43.784691 -79.227304    ON
# 21                                        NaN  43.721732 -79.409600   NaN
# 22                                        NaN  43.723286 -79.412222   NaN
# 23                                30 Bond St.  43.653585 -79.378843    ON
# 24                           350 Victoria St.  43.658585 -79.380622    ON
# 25                                      Bloor  43.660759 -79.424018   NaN
# 26                       958 Broadview avenue  43.681763 -79.358246    ON
# 27                       2201 Eglinton Ave. E  43.728081 -79.278856    ON
# 28                                        NaN  43.645700 -79.611690    ON
# 29                             951 Carlaw Ave  43.684631 -79.348862    ON
#
#    postalCode
# 0         NaN
# 1     M5T 2G5
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9     M4V 1H7
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15    L5P 1B2
# 16        NaN
# 17        NaN
# 18    M2L 2V2
# 19    M2K 1E1
# 20    M1G 3T8
# 21        NaN
# 22        NaN
# 23    M5B 1W8
# 24    M5B 2K3
# 25        NaN
# 26        NaN
# 27    M1L 4S2
# 28    L4W 5N2
# 29        NaN

# %%
#further cleaning
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                              name         categories               address  \
# 1               Stay Cafeteria 慢走   Asian Restaurant       388 Spadina Ave
# 9   De La Salle College Cafeteria  College Cafeteria    131 Farnham Avenue
# 15                  The Cafeteria              Diner            Terminal 1
# 18           Windfields Cafeteria          Cafeteria            Banbury Rd
# 19                      Cafeteria         Food Court        4001 Leslie St
# 20  Cafeteria, Centennial College  College Cafeteria      940 Progress Ave
# 23                     Marketeria         Restaurant           30 Bond St.
# 24                        The Hub  College Cafeteria      350 Victoria St.
# 27   2201 Eglinton Ave. Cafeteria          Cafeteria  2201 Eglinton Ave. E
#
#           lat        lng state postalCode
# 1   43.655454 -79.399163    ON    M5T 2G5
# 9   43.683003 -79.397815    ON    M4V 1H7
# 15  43.682246 -79.611691    ON    L5P 1B2
# 18  43.755862 -79.370649    ON    M2L 2V2
# 19  43.769373 -79.362580    ON    M2K 1E1
# 20  43.784691 -79.227304    ON    M1G 3T8
# 23  43.653585 -79.378843    ON    M5B 1W8
# 24  43.658585 -79.380622    ON    M5B 2K3
# 27  43.728081 -79.278856    ON    M1L 4S2

# %% [markdown]
# ## Searching Shopping stores

# %%
search_query = 'Shopping'
radius = 2000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=IFYHBS5DHCADMSLQKHLENQSFIFKFSMMHSLUTCWPM4HO4MI5H&client_secret=MRGFMOSL4AEOWUR3SUBJSZK2XSEZAVKNJDBCOFSOOV02XZHF&ll=43.6534817,-79.3839347&v=20180604&query=Shopping&radius=2000&limit=30'

# %%
# Sending GET Request to examine results
sresults = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# changing venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                                        name  \
# 0  4ad4c062f964a520fcf720e3                Dragon City Shopping Mall 龍城
# 1  5840cafe06f1a34af80cc609  Saks Fifth Avenue Club - Personal Shopping
# 2  4ad77a12f964a520260b21e3                     CF Toronto Eaton Centre
# 3  4b9e86dff964a520e6eb36e3                TD Centre Shopping Concourse
# 4  4ef4758261af302a97b71465                        Last Minute Shopping
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1595800678    False
# 1  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...  v-1595800678    False
# 2  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1595800678    False
# 3  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...  v-1595800678    False
# 4  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...  v-1595800678    False
#
#      location.address location.crossStreet  location.lat  location.lng  \
# 0     280 Spadina Ave       at Dundas St W     43.652774    -79.398222
# 1    176 Yonge Street    Queen Street West     43.651810    -79.379192
# 2        220 Yonge St  btwn Queen & Dundas     43.654540    -79.380677
# 3  66 Wellington St W    btw York & Bay St     43.647184    -79.380932
# 4                 NaN                  NaN     43.642740    -79.412871
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...               1153
# 1  [{'label': 'display', 'lat': 43.65181, 'lng': ...                424
# 2                                                NaN                287
# 3  [{'label': 'display', 'lat': 43.64718424611984...                741
# 4  [{'label': 'display', 'lat': 43.64274007508189...               2619
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5T 3A5          CA       Toronto             ON
# 1             M5C 2L7          CA       Toronto             ON
# 2             M5B 2H1          CA       Toronto             ON
# 3             M5K 1A1          CA       Toronto             ON
# 4                 NaN          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1           Canada  [176 Yonge Street (Queen Street West), Toronto...
# 2           Canada  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 3           Canada  [66 Wellington St W (btw York & Bay St), Toron...
# 4           Canada                               [Toronto ON, Canada]
#
#            location.neighborhood
# 0                            NaN
# 1                            NaN
# 2  Downtown Toronto, Toronto, ON
# 3                            NaN
# 4                            NaN

# %% [markdown]
# ### Clean dataframe

# %%
# keep columns that include venue name, and anything associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filtering the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 2                     CF Toronto Eaton Centre     Shopping Mall
# 3                TD Centre Shopping Concourse     Shopping Mall
# 4                        Last Minute Shopping  Department Store
#
#               address          crossStreet        lat        lng  \
# 0     280 Spadina Ave       at Dundas St W  43.652774 -79.398222
# 1    176 Yonge Street    Queen Street West  43.651810 -79.379192
# 2        220 Yonge St  btwn Queen & Dundas  43.654540 -79.380677
# 3  66 Wellington St W    btw York & Bay St  43.647184 -79.380932
# 4                 NaN                  NaN  43.642740 -79.412871
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.65277367198862...      1153    M5T 3A5  CA
# 1  [{'label': 'display', 'lat': 43.65181, 'lng': ...       424    M5C 2L7  CA
# 2                                                NaN       287    M5B 2H1  CA
# 3  [{'label': 'display', 'lat': 43.64718424611984...       741    M5K 1A1  CA
# 4  [{'label': 'display', 'lat': 43.64274007508189...      2619        NaN  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [280 Spadina Ave (at Dundas St W), Toronto ON ...
# 1  Toronto    ON  Canada  [176 Yonge Street (Queen Street West), Toronto...
# 2  Toronto    ON  Canada  [220 Yonge St (btwn Queen & Dundas), Toronto O...
# 3  Toronto    ON  Canada  [66 Wellington St W (btw York & Bay St), Toron...
# 4  Toronto    ON  Canada                               [Toronto ON, Canada]
#
#                     neighborhood                        id
# 0                            NaN  4ad4c062f964a520fcf720e3
# 1                            NaN  5840cafe06f1a34af80cc609
# 2  Downtown Toronto, Toronto, ON  4ad77a12f964a520260b21e3
# 3                            NaN  4b9e86dff964a520e6eb36e3
# 4                            NaN  4ef4758261af302a97b71465

# %%
#further cleaning
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'neighborhood', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                                          name        categories  \
# 0                Dragon City Shopping Mall 龍城     Shopping Mall
# 1  Saks Fifth Avenue Club - Personal Shopping  Department Store
# 2                     CF Toronto Eaton Centre     Shopping Mall
# 3                TD Centre Shopping Concourse     Shopping Mall
# 4                        Last Minute Shopping  Department Store
# 5             Yellow Pages - RedFlagDeals.com            Office
#
#               address        lat        lng postalCode state
# 0     280 Spadina Ave  43.652774 -79.398222    M5T 3A5    ON
# 1    176 Yonge Street  43.651810 -79.379192    M5C 2L7    ON
# 2        220 Yonge St  43.654540 -79.380677    M5B 2H1    ON
# 3  66 Wellington St W  43.647184 -79.380932    M5K 1A1    ON
# 4                 NaN  43.642740 -79.412871        NaN    ON
# 5   461 King St. West  43.647958 -79.396006    M5V 1K4    ON

# %%
#further cleaning
# delete rows which its category is not Shopping Mall
df_Shopping = clean_Shopping_dataframe2[clean_Shopping_dataframe2.categories == 'Shopping Mall']
df_Shopping
# Out:
#                            name     categories             address        lat  \
# 0  Dragon City Shopping Mall 龍城  Shopping Mall     280 Spadina Ave  43.652774
# 2       CF Toronto Eaton Centre  Shopping Mall        220 Yonge St  43.654540
# 3  TD Centre Shopping Concourse  Shopping Mall  66 Wellington St W  43.647184
#
#          lng postalCode state
# 0 -79.398222    M5T 3A5    ON
# 2 -79.380677    M5B 2H1    ON
# 3 -79.380932    M5K 1A1    ON

# %% [markdown]
# # Map generation to visualize hotels, shopping stores and Cafeteria and understanding clustering

# %%
# create dataframe of hotels, shopping stores and Cafeteria
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df
# Out:
#                              name         categories               address  \
# 0                  St Regis Hotel              Hotel            325 Bay St
# 1      The Adelaide Hotel Toronto              Hotel            325 Bay St
# 2               Stay Cafeteria 慢走   Asian Restaurant       388 Spadina Ave
# 3   De La Salle College Cafeteria  College Cafeteria    131 Farnham Avenue
# 4                   The Cafeteria              Diner            Terminal 1
# 5            Windfields Cafeteria          Cafeteria            Banbury Rd
# 6                       Cafeteria         Food Court        4001 Leslie St
# 7   Cafeteria, Centennial College  College Cafeteria      940 Progress Ave
# 8                      Marketeria         Restaurant           30 Bond St.
# 9                         The Hub  College Cafeteria      350 Victoria St.
# 10   2201 Eglinton Ave. Cafeteria          Cafeteria  2201 Eglinton Ave. E
# 11   Dragon City Shopping Mall 龍城      Shopping Mall       280 Spadina Ave
# 12        CF Toronto Eaton Centre      Shopping Mall          220 Yonge St
# 13   TD Centre Shopping Concourse      Shopping Mall    66 Wellington St W
#
#           lat        lng postalCode state
# 0   43.649770 -79.380701    M5H 4G3    ON
# 1   43.649831 -79.380164    M5H 4G3    ON
# 2   43.655454 -79.399163    M5T 2G5    ON
# 3   43.683003 -79.397815    M4V 1H7    ON
# 4   43.682246 -79.611691    L5P 1B2    ON
# 5   43.755862 -79.370649    M2L 2V2    ON
# 6   43.769373 -79.362580    M2K 1E1    ON
# 7   43.784691 -79.227304    M1G 3T8    ON
# 8   43.653585 -79.378843    M5B 1W8    ON
# 9   43.658585 -79.380622    M5B 2K3    ON
# 10  43.728081 -79.278856    M1L 4S2    ON
# 11  43.652774 -79.398222    M5T 3A5    ON
# 12  43.654540 -79.380677    M5B 2H1    ON
# 13  43.647184 -79.380932    M5K 1A1    ON

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria 
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Map Generation to visualize Park, Restaurant and Cafeteria and understand clustering

# %%
# create dataframe of Park, Restaurant and Cafeteria
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
#                                               name            categories  \
# 0                                     Queen's Park                  Park
# 1                              Riverdale Park West                  Park
# 2                           Trinity Bellwoods Park                  Park
# 3                              Riverdale Park East                  Park
# 4                             Bellevue Square Park                  Park
# 5                               Canoe Landing Park                  Park
# 6                                  Coronation Park                  Park
# 7                                Barbara Hall Park                  Park
# 8                                        High Park                  Park
# 9                   The Hot House Restaurant & Bar   American Restaurant
# 10                 Hemispheres Restaurant & Bistro   American Restaurant
# 11                           Victoria's Restaurant            Restaurant
# 12                          Rol San Restaurant 龍笙棧    Dim Sum Restaurant
# 13                  Goldstone Noodle Restaurant 金石          Noodle House
# 14                    Aroma Fine Indian Restaurant     Indian Restaurant
# 15         Tasty's Caribbean Restaurant & Catering  Caribbean Restaurant
# 16                               Studio Restaurant        Breakfast Spot
# 17                          Azure Restaurant & Bar            Restaurant
# 18                   Green Tea Restaurant Downtown    Chinese Restaurant
# 19                     Cottage Restaurant & Lounge       Thai Restaurant
# 20               Kensington Cornerstone Restaurant        Breakfast Spot
# 21                        Ka Chi Korean Restaurant     Korean Restaurant
# 22                         Victor Restaurant & Bar                   Bar
# 23                         Swatow Restaurant 汕頭小食家    Chinese Restaurant
# 24                                  360 Restaurant              Wine Bar
# 25                        New Sky Restaurant 小沙田食家    Chinese Restaurant
# 26  Sassafraz | Cafe | Restaurant | Private Events           Event Space
# 27                           Restaurant | Adelaide            Restaurant
# 28             Richtree Natural Market Restaurants            Restaurant
# 29                    Yueh Tung Chinese Restaurant    Chinese Restaurant
# 30                               Stay Cafeteria 慢走      Asian Restaurant
# 31                   De La Salle College Cafeteria     College Cafeteria
# 32                                   The Cafeteria                 Diner
# 33                            Windfields Cafeteria             Cafeteria
# 34                                       Cafeteria            Food Court
# 35                   Cafeteria, Centennial College     College Cafeteria
# 36                                      Marketeria            Restaurant
# 37                                         The Hub     College Cafeteria
# 38                    2201 Eglinton Ave. Cafeteria             Cafeteria
#
#                             address        lat        lng postalCode state
# 0                   University Ave.  43.663946 -79.392180    M5R 2E8    ON
# 1                   500 Gerrard St.  43.666048 -79.360941    M5A 2H3    ON
# 2                1053 Dundas St. W.  43.647072 -79.413756    M5H 2N2    ON
# 3                 550 Broadview Ave  43.669951 -79.355493    M4K 2P1    ON
# 4      btwn Bellevue & Augusta Ave.  43.653610 -79.402199    M5T 2N4    ON
# 5                 50 Fort York Blvd  43.638762 -79.397067    M5V 3Z1    ON
# 6            711 Lake Shore Blvd. W  43.634553 -79.405403    M5V 3T7    ON
# 7                     519 Church St  43.666879 -79.381068    M4Y 2K9    ON
# 8                  1873 Bloor St. W  43.646479 -79.463425    M6R 2Z3    ON
# 9                      35 Church St  43.648824 -79.373702    M5E 1T3    ON
# 10              110 Chestnut Street  43.654884 -79.385931    M5G 1R3    ON
# 11              37 King Street East  43.649298 -79.376431    M5C 1E9    ON
# 12                 323 Spadina Ave.  43.654318 -79.398650    M5T 2E9    ON
# 13                  266 Spadina Ave  43.652278 -79.398039    M5T 2E4    ON
# 14                   287 King St. W  43.646463 -79.389644    M5V 1J5    ON
# 15                  405 Spadina Ave  43.656794 -79.399251    M5T 2G6    ON
# 16                   389 Church St.  43.661500 -79.379319        M5B    ON
# 17                   225 Front St W  43.644749 -79.385113    M5V 2X3    ON
# 18  261 Spadina Avenue. Upper level  43.652488 -79.397501    M5T 2E3    ON
# 19                   338 Jarvis St.  43.662770 -79.376894    M4Y 2G6    ON
# 20               2A Kensington Ave.  43.652803 -79.399958    M5T 2J7    ON
# 21                  8 St Andrew St.  43.654307 -79.399277    M5T 1K6    ON
# 22                 30 Mercer Street  43.645634 -79.391125    M5V 1H3    ON
# 23                 309 Spadina Ave.  43.653866 -79.398334    M5T 2E6    ON
# 24                   301 Front St W  43.642537 -79.387042    M5V 2T6    ON
# 25                 353 Spadina Ave.  43.655337 -79.398897    M5T 2G3    ON
# 26            100 Cumberland Street  43.670342 -79.391041    M5R 1A6    ON
# 27          325 Bay St (31st floor)  43.649563 -79.380590        M5H    ON
# 28                    14 Queen St W  43.652614 -79.380231    M5H 3X4    ON
# 29                126 Elizabeth St.  43.655281 -79.385337    M5G 1P5    ON
# 30                  388 Spadina Ave  43.655454 -79.399163    M5T 2G5    ON
# 31               131 Farnham Avenue  43.683003 -79.397815    M4V 1H7    ON
# 32                       Terminal 1  43.682246 -79.611691    L5P 1B2    ON
# 33                       Banbury Rd  43.755862 -79.370649    M2L 2V2    ON
# 34                   4001 Leslie St  43.769373 -79.362580    M2K 1E1    ON
# 35                 940 Progress Ave  43.784691 -79.227304    M1G 3T8    ON
# 36                      30 Bond St.  43.653585 -79.378843    M5B 1W8    ON
# 37                 350 Victoria St.  43.658585 -79.380622    M5B 2K3    ON
# 38             2201 Eglinton Ave. E  43.728081 -79.278856    M1L 4S2    ON

# %%
# Generate map to visualize park neighbourhood including Restaurant and Cafeteria 
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
